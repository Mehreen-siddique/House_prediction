# %%
from google.colab import files
uploaded = files.upload

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("house_data.csv")
df
df.shape
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.tail(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1456         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1457         Lvl    AllPub  ...        0    NaN  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1459         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False        False    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False        False    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1455  False       False     False        False    False   False   True
# 1456  False       False     False        False    False   False   True
# 1457  False       False     False        False    False   False   True
# 1458  False       False     False        False    False   False   True
# 1459  False       False     False        False    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(7829)

# %%
df['Id'].sum()
# Out:
# np.int64(1066530)

# %%
df['Id'].isna().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# Id
# MSSubClass
# MSZoning
# LotFrontage
# LotArea
# Street
# Alley
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition1
# Condition2
# BldgType
# HouseStyle
# OverallQual
# OverallCond
# YearBuilt
# YearRemodAdd
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# MasVnrArea
# ExterQual
# ExterCond
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinSF1
# BsmtFinType2
# BsmtFinSF2
# BsmtUnfSF
# TotalBsmtSF
# Heating
# HeatingQC
# CentralAir
# Electrical
# 1stFlrSF
# 2ndFlrSF
# LowQualFinSF
# GrLivArea
# BsmtFullBath
# BsmtHalfBath
# FullBath
# HalfBath
# BedroomAbvGr
# KitchenAbvGr
# KitchenQual
# TotRmsAbvGrd
# Functional
# Fireplaces
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageCars
# GarageArea
# GarageQual
# GarageCond
# PavedDrive
# WoodDeckSF
# OpenPorchSF
# EnclosedPorch
# 3SsnPorch
# ScreenPorch
# PoolArea
# PoolQC
# Fence
# MiscFeature
# MiscVal
# MoSold
# YrSold
# SaleType
# ...

# %%
for i in df.columns:
    print(i, df[i].dtypes)
# Out:
# Id int64
# MSSubClass int64
# MSZoning object
# LotFrontage float64
# LotArea int64
# Street object
# Alley object
# LotShape object
# LandContour object
# Utilities object
# LotConfig object
# LandSlope object
# Neighborhood object
# Condition1 object
# Condition2 object
# BldgType object
# HouseStyle object
# OverallQual int64
# OverallCond int64
# YearBuilt int64
# YearRemodAdd int64
# RoofStyle object
# RoofMatl object
# Exterior1st object
# Exterior2nd object
# MasVnrType object
# MasVnrArea float64
# ExterQual object
# ExterCond object
# Foundation object
# BsmtQual object
# BsmtCond object
# BsmtExposure object
# BsmtFinType1 object
# BsmtFinSF1 int64
# BsmtFinType2 object
# BsmtFinSF2 int64
# BsmtUnfSF int64
# TotalBsmtSF int64
# Heating object
# HeatingQC object
# CentralAir object
# Electrical object
# 1stFlrSF int64
# 2ndFlrSF int64
# LowQualFinSF int64
# GrLivArea int64
# BsmtFullBath int64
# BsmtHalfBath int64
# FullBath int64
# HalfBath int64
# BedroomAbvGr int64
# ...

# %%
for i in df.columns:
    print(i, df[i].dtypes, df[i].isna().sum())
# Out:
# Id int64 0
# MSSubClass int64 0
# MSZoning object 0
# LotFrontage float64 259
# LotArea int64 0
# Street object 0
# Alley object 1369
# LotShape object 0
# LandContour object 0
# Utilities object 0
# LotConfig object 0
# LandSlope object 0
# Neighborhood object 0
# Condition1 object 0
# Condition2 object 0
# BldgType object 0
# HouseStyle object 0
# OverallQual int64 0
# OverallCond int64 0
# YearBuilt int64 0
# YearRemodAdd int64 0
# RoofStyle object 0
# RoofMatl object 0
# Exterior1st object 0
# Exterior2nd object 0
# MasVnrType object 872
# MasVnrArea float64 8
# ExterQual object 0
# ExterCond object 0
# Foundation object 0
# BsmtQual object 37
# BsmtCond object 37
# BsmtExposure object 38
# BsmtFinType1 object 37
# BsmtFinSF1 int64 0
# BsmtFinType2 object 38
# BsmtFinSF2 int64 0
# BsmtUnfSF int64 0
# TotalBsmtSF int64 0
# Heating object 0
# HeatingQC object 0
# CentralAir object 0
# Electrical object 1
# 1stFlrSF int64 0
# 2ndFlrSF int64 0
# LowQualFinSF int64 0
# ...

# %%
for i in df.columns:
    if(df[i].isna().sum() != 0):
            print(i, df[i].dtypes, df[i].isna().sum())
# Out:
# LotFrontage float64 259
# Alley object 1369
# MasVnrType object 872
# MasVnrArea float64 8
# BsmtQual object 37
# BsmtCond object 37
# BsmtExposure object 38
# BsmtFinType1 object 37
# BsmtFinType2 object 38
# Electrical object 1
# FireplaceQu object 690
# GarageType object 81
# GarageYrBlt float64 81
# GarageFinish object 81
# GarageQual object 81
# GarageCond object 81
# PoolQC object 1453
# Fence object 1179
# MiscFeature object 1406

# %%
for i in df.columns:
    if(df[i].isna().sum() != 0 and df[i].dtypes == 'object'):
            print(i, df[i].dtypes, df[i].isna().sum())
# Out:
# Alley object 1369
# MasVnrType object 872
# BsmtQual object 37
# BsmtCond object 37
# BsmtExposure object 38
# BsmtFinType1 object 37
# BsmtFinType2 object 38
# Electrical object 1
# FireplaceQu object 690
# GarageType object 81
# GarageFinish object 81
# GarageQual object 81
# GarageCond object 81
# PoolQC object 1453
# Fence object 1179
# MiscFeature object 1406

# %%
for i in df.columns:
    if(df[i].isna().sum() != 0 and df[i].dtypes == 'float64'):
            print(i, df[i].dtypes, df[i].isna().sum())
# Out:
# LotFrontage float64 259
# MasVnrArea float64 8
# GarageYrBlt float64 81

# %%
df['Alley'].isna().sum()
# Out:
# np.int64(1369)

# %%
len(df)
# Out:
# 1460

# %%
(df.isna().sum() / len(df))* 100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
for i in df.columns:
        if(df[i].isna().sum() != 0):
            print(i, ((df.isna().sum() / len(df))* 100).round(2) )
# Out:
# LotFrontage Id                0.00
# MSSubClass        0.00
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
#                  ...
# MoSold            0.00
# YrSold            0.00
# SaleType          0.00
# SaleCondition     0.00
# SalePrice         0.00
# Length: 81, dtype: float64
# Alley Id                0.00
# MSSubClass        0.00
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
#                  ...
# MoSold            0.00
# YrSold            0.00
# SaleType          0.00
# SaleCondition     0.00
# SalePrice         0.00
# Length: 81, dtype: float64
# MasVnrType Id                0.00
# MSSubClass        0.00
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
#                  ...
# MoSold            0.00
# YrSold            0.00
# SaleType          0.00
# SaleCondition     0.00
# SalePrice         0.00
# Length: 81, dtype: float64
# MasVnrArea Id                0.00
# MSSubClass        0.00
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull(), cbar = False , cmap = "viridis")
plt.title("Missing value heatmap")
plt.show()

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.dropna(thresh= len(df) * 0.5, axis = 1, inplace = True)

# %%
df.shape
# Out:
# (1460, 76)

# %%
for i in df:
    print(i , df[i].dtypes)
# Out:
# Id int64
# MSSubClass int64
# MSZoning object
# LotFrontage float64
# LotArea int64
# Street object
# LotShape object
# LandContour object
# Utilities object
# LotConfig object
# LandSlope object
# Neighborhood object
# Condition1 object
# Condition2 object
# BldgType object
# HouseStyle object
# OverallQual int64
# OverallCond int64
# YearBuilt int64
# YearRemodAdd int64
# RoofStyle object
# RoofMatl object
# Exterior1st object
# Exterior2nd object
# MasVnrArea float64
# ExterQual object
# ExterCond object
# Foundation object
# BsmtQual object
# BsmtCond object
# BsmtExposure object
# BsmtFinType1 object
# BsmtFinSF1 int64
# BsmtFinType2 object
# BsmtFinSF2 int64
# BsmtUnfSF int64
# TotalBsmtSF int64
# Heating object
# HeatingQC object
# CentralAir object
# Electrical object
# 1stFlrSF int64
# 2ndFlrSF int64
# LowQualFinSF int64
# GrLivArea int64
# BsmtFullBath int64
# BsmtHalfBath int64
# FullBath int64
# HalfBath int64
# BedroomAbvGr int64
# KitchenAbvGr int64
# ...

# %%
for i in df:
    if(df[i].dtypes == 'float64'):
        print(i , df[i].dtypes , df[i].isna().sum())
# Out:
# LotFrontage float64 259
# MasVnrArea float64 8
# GarageYrBlt float64 81

# %%
for i in df:
    if(df[i].dtypes == 'float64' and df[i].isna().sum() != 0):
        print(i , df[i].dtypes , df[i].isna().sum())
# Out:
# LotFrontage float64 259
# MasVnrArea float64 8
# GarageYrBlt float64 81

# %%
df['LotFrontage'].mean()
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
for i in df:
    if(df[i].dtypes == 'float64' and df[i].isna().sum()!=0):
        df[i] = df[i].fillna(df[i].mean())
        print(i, df[i].dtypes, df[i].isna().sum())
# Out:
# MasVnrArea float64 0
# GarageYrBlt float64 0

# %%
df.shape
# Out:
# (1460, 76)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
for i in df:
     if(df[i].dtypes == 'object' and df[i].isna().sum() != 0):
         print(i, df[i].dtypes, df[i].isna().sum())
# Out:
# BsmtQual object 37
# BsmtCond object 37
# BsmtExposure object 38
# BsmtFinType1 object 37
# BsmtFinType2 object 38
# Electrical object 1
# FireplaceQu object 690
# GarageType object 81
# GarageFinish object 81
# GarageQual object 81
# GarageCond object 81

# %%
df.drop('FireplaceQu', axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
df['BsmtQual'].value_counts().to_frame()
# Out:
#           count
# BsmtQual
# TA          649
# Gd          618
# Ex          121
# Fa           35

# %%
for i in df:
    if(df[i].dtypes == 'object'):
        print(df[i].value_counts())
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64
# LotConfig
# Inside     1052
# Corner      263
# CulDSac      94
# FR2          47
# FR3           4
# Name: count, dtype: int64
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# SWISU       25
# ...

# %%
for i in df:
     if(df[i].dtypes == 'object' and df[i].isna().sum() != 0):
         print(i, df[i].dtypes, df[i].isna().sum())
# Out:
# BsmtQual object 37
# BsmtCond object 37
# BsmtExposure object 38
# BsmtFinType1 object 37
# BsmtFinType2 object 38
# Electrical object 1
# FireplaceQu object 690
# GarageType object 81
# GarageFinish object 81
# GarageQual object 81
# GarageCond object 81

# %%
df.shape
# Out:
# (1460, 76)

# %%
df.drop('FireplaceQu', axis = 1, inplace = True)

# %%
df.dropna(subset = 'BsmtQual', axis = 0, inplace = True)

# %%
df.shape
# Out:
# (1423, 75)

# %%
for i in df:
     if(df[i].dtypes == 'object' and df[i].isna().sum() != 0):
         df.dropna(subset = i, axis = 0, inplace = True)
         print(i, df[i].dtypes, df[i].isna().sum())
# Out:
# BsmtExposure object 0
# BsmtFinType2 object 0
# Electrical object 0
# GarageType object 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1346 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1346 non-null   int64
#  1   MSSubClass     1346 non-null   int64
#  2   MSZoning       1346 non-null   object
#  3   LotFrontage    1346 non-null   float64
#  4   LotArea        1346 non-null   int64
#  5   Street         1346 non-null   object
#  6   LotShape       1346 non-null   object
#  7   LandContour    1346 non-null   object
#  8   Utilities      1346 non-null   object
#  9   LotConfig      1346 non-null   object
#  10  LandSlope      1346 non-null   object
#  11  Neighborhood   1346 non-null   object
#  12  Condition1     1346 non-null   object
#  13  Condition2     1346 non-null   object
#  14  BldgType       1346 non-null   object
#  15  HouseStyle     1346 non-null   object
#  16  OverallQual    1346 non-null   int64
# ...

# %%
df[df['MSSubClass']==60]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL    65.000000     8450   Pave      Reg
# 2        3          60       RL    68.000000    11250   Pave      IR1
# 4        5          60       RL    84.000000    14260   Pave      IR1
# 7        8          60       RL    70.049958    10382   Pave      IR1
# 11      12          60       RL    85.000000    11924   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1433  1434          60       RL    93.000000    10261   Pave      IR1
# 1439  1440          60       RL    80.000000    11584   Pave      Reg
# 1442  1443          60       FV    85.000000    11003   Pave      Reg
# 1447  1448          60       RL    80.000000    10000   Pave      Reg
# 1455  1456          60       RL    62.000000     7917   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
(df['Id'] == 5).sum()
# Out:
# np.int64(1)

# %%
(df['EnclosedPorch'] == 0).sum()
# Out:
# np.int64(1162)

# %%
for i in df:
    if(df[i].dtypes == 'int64' and (df[i] == 0).sum() != 0 ):
        print(i, df[i].dtypes, (df[i] == 0).sum() )
# Out:
# BsmtFinSF1 int64 394
# BsmtFinSF2 int64 1184
# BsmtUnfSF int64 73
# 2ndFlrSF int64 753
# LowQualFinSF int64 1328
# BsmtFullBath int64 766
# BsmtHalfBath int64 1266
# FullBath int64 8
# HalfBath int64 811
# BedroomAbvGr int64 6
# Fireplaces int64 595
# WoodDeckSF int64 675
# OpenPorchSF int64 575
# EnclosedPorch int64 1162
# 3SsnPorch int64 1323
# ScreenPorch int64 1230
# PoolArea int64 1339
# MiscVal int64 1299

# %%
for i in df:
    if(df[i].dtypes == 'int64' and (df[i] == 0).sum() != 0 ):
        print(i, df[i].dtypes, (df[i] == 0).sum(), (((df[i] == 0).sum()/ len(df)) *100).round(2))
# Out:
# BsmtFinSF1 int64 394 29.27
# BsmtFinSF2 int64 1184 87.96
# BsmtUnfSF int64 73 5.42
# 2ndFlrSF int64 753 55.94
# LowQualFinSF int64 1328 98.66
# BsmtFullBath int64 766 56.91
# BsmtHalfBath int64 1266 94.06
# FullBath int64 8 0.59
# HalfBath int64 811 60.25
# BedroomAbvGr int64 6 0.45
# Fireplaces int64 595 44.21
# WoodDeckSF int64 675 50.15
# OpenPorchSF int64 575 42.72
# EnclosedPorch int64 1162 86.33
# 3SsnPorch int64 1323 98.29
# ScreenPorch int64 1230 91.38
# PoolArea int64 1339 99.48
# MiscVal int64 1299 96.51

# %%
for i in df:
    if(df[i].dtypes == 'int64' and (df[i] == 0).sum() != 0 and (((df[i] == 0).sum()/ len(df)) *100).round(2) >= 50.0 ):
        print(i, df[i].dtypes, (df[i] == 0).sum(), (((df[i] == 0).sum()/ len(df)) *100).round(2))
# Out:
# BsmtFinSF2 int64 1184 87.96
# 2ndFlrSF int64 753 55.94
# LowQualFinSF int64 1328 98.66
# BsmtFullBath int64 766 56.91
# BsmtHalfBath int64 1266 94.06
# HalfBath int64 811 60.25
# WoodDeckSF int64 675 50.15
# EnclosedPorch int64 1162 86.33
# 3SsnPorch int64 1323 98.29
# ScreenPorch int64 1230 91.38
# PoolArea int64 1339 99.48
# MiscVal int64 1299 96.51

# %%
for i in df:
    if(df[i].dtypes == 'int64' and (df[i] == 0).sum() != 0 and (((df[i] == 0).sum()/ len(df)) *100).round(2) >= 50.0 ):
        df.drop(i, axis = 1, inplace = True)
       # print(i, df[i].dtypes, (df[i] == 0).sum(), (((df[i] == 0).sum()/ len(df)) *100).round(2))

# %%
df.shape
# Out:
# (1346, 63)

# %%
for i in df:
    if(df[i].dtypes == 'int64' and (df[i] == 0).sum() != 0 and (((df[i] == 0).sum()/ len(df)) *100).round(2) >= 50.0 ):
        df[i] = df[i].replace(0, df[i].mean())
        print(i, df[i].dtypes, (df[i] == 0).sum(), (((df[i] == 0).sum()/ len(df)) *100).round(2))

# %%
df.shape
# Out:
# (1346, 63)

# %%
df.hist(figsize = (12,8), bins = 30)
plt.tight_layout()
plt.show()

# %%
df.drop('MasVnrArea', axis = 1, inplace = True)

# %%
df.shape
# Out:
# (1346, 62)

# %%
for col in df.columns:
    if(df[col].dtypes == 'object'):
        print(df[col].value_counts())
        df[col].value_counts().plot(kind = "bar", title = col)
        plt.show()
# Out:
# MSZoning
# RL         1071
# RM          191
# FV           65
# RH           11
# C (all)       8
# Name: count, dtype: int64
# Street
# Pave    1341
# Grvl       5
# Name: count, dtype: int64
# LotShape
# Reg    835
# IR1    461
# IR2     40
# IR3     10
# Name: count, dtype: int64
# LandContour
# Lvl    1214
# Bnk      52
# HLS      48
# Low      32
# Name: count, dtype: int64
# Utilities
# AllPub    1345
# NoSeWa       1
# Name: count, dtype: int64
# LotConfig
# Inside     963
# Corner     245
# CulDSac     91
# FR2         43
# FR3          4
# Name: count, dtype: int64
# LandSlope
# Gtl    1273
# Mod      61
# Sev      12
# Name: count, dtype: int64
# Neighborhood
# NAmes      209
# CollgCr    147
# OldTown    100
# Somerst     86
# Gilbert     78
# NridgHt     76
# NWAmes      73
# Edwards     70
# Sawyer      69
# SawyerW     54
# Crawfor     51
# BrkSide     47
# Mitchel     42
# NoRidge     41
# Timber      37
# IDOTRR      29
# ClearCr     26
# StoneBr     25
# ...

# %% [markdown]
# #step No 5 Encode Categorical Variables

# %%
df['SaleCondition'].value_counts().to_frame()
# Out:
#                count
# SaleCondition
# Normal          1108
# Partial          123
# Abnorml           86
# Family            20
# Alloca             8
# AdjLand            1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
df['SaleCondition'] = le.fit_transform(df['SaleCondition'])

# %%
df['SaleCondition'].value_counts().to_frame()
# Out:
#                count
# SaleCondition
# 4               1108
# 5                123
# 0                 86
# 3                 20
# 2                  8
# 1                  1

# %%
df['SaleCondition'].dtypes
# Out:
# dtype('int64')

# %%
for i in df:
    if(df[i].dtypes == 'object'):
        df[i] = le.fit_transform(df[i])
        print(i,df[i].dtypes )
# Out:
# MSZoning int64
# Street int64
# LotShape int64
# LandContour int64
# Utilities int64
# LotConfig int64
# LandSlope int64
# Neighborhood int64
# Condition1 int64
# Condition2 int64
# BldgType int64
# HouseStyle int64
# RoofStyle int64
# RoofMatl int64
# Exterior1st int64
# Exterior2nd int64
# ExterQual int64
# ExterCond int64
# Foundation int64
# BsmtQual int64
# BsmtCond int64
# BsmtExposure int64
# BsmtFinType1 int64
# BsmtFinType2 int64
# Heating int64
# HeatingQC int64
# CentralAir int64
# Electrical int64
# KitchenQual int64
# Functional int64
# GarageType int64
# GarageFinish int64
# GarageQual int64
# GarageCond int64
# PavedDrive int64
# SaleType int64

# %%
for i in df:
    print(df[i].value_counts().to_frame())
# Out:
#       count
# Id
# 1460      1
# 1         1
# 1441      1
# 1440      1
# 1439      1
# ...     ...
# 7         1
# 6         1
# 5         1
# 4         1
# 3         1
#
# [1346 rows x 1 columns]
#             count
# MSSubClass
# 20            506
# 60            297
# 50            129
# 120            87
# 160            61
# 80             57
# 70             57
# 30             51
# 90             28
# 190            21
# 85             19
# 75             14
# 45              9
# 180             6
# 40              4
#           count
# MSZoning
# 3          1071
# 4           191
# 1            65
# 2            11
# 0             8
#              count
# LotFrontage
# 70.049958      246
# 60.000000      120
# 80.000000       67
# 70.000000       63
# 75.000000       51
# ...            ...
# 149.000000       1
# 182.000000       1
# 160.000000       1
# 152.000000       1
# 46.000000        1
#
# [108 rows x 1 columns]
#          count
# LotArea
# 9600        23
# ...

# %%
df.hist(figsize = (12,8), bins = 30)
plt.tight_layout()
plt.show()

# %%
#step 6  feature engineering & selection

# %%
df. iloc [: 5, 1:15]
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          60         3         65.0     8450       1         3            3
# 1          20         3         80.0     9600       1         3            3
# 2          60         3         68.0    11250       1         0            3
# 3          70         3         60.0     9550       1         0            3
# 4          60         3         84.0    14260       1         0            3
#
#    Utilities  LotConfig  LandSlope  Neighborhood  Condition1  Condition2  \
# 0          0          4          0             5           2           2
# 1          0          2          0            24           1           2
# 2          0          4          0             5           2           2
# 3          0          0          0             6           2           2
# 4          0          2          0            15           2           2
#
#    BldgType
# 0         0
# 1         0
# 2         0
# ...

# %%
correlation = df.corr()
correlation
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.016151 -0.009639    -0.011789 -0.036507
# MSSubClass     0.016151    1.000000  0.017811    -0.360201 -0.135995
# MSZoning      -0.009639    0.017811  1.000000    -0.088991 -0.023951
# LotFrontage   -0.011789   -0.360201 -0.088991     1.000000  0.299898
# LotArea       -0.036507   -0.135995 -0.023951     0.299898  1.000000
# ...                 ...         ...       ...          ...       ...
# MoSold         0.023310   -0.015948 -0.019094     0.014158 -0.001991
# YrSold         0.000018   -0.021460 -0.022157     0.010726 -0.013415
# SaleType       0.013126    0.010772  0.095048    -0.024890  0.014859
# SaleCondition  0.001819   -0.010778 -0.008889     0.046891  0.028344
# SalePrice     -0.026857   -0.081120 -0.162067     0.329520  0.253854
#
#                  Street  LotShape  LandContour  Utilities  LotConfig  ...  \
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(correlation , square = True, fmt = '.1f',annot = True, annot_kws = {'size':12})
# Out:
# <Axes: >

# %%
df.iloc[ :5,]
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  Utilities  LotConfig  ...  GarageArea  GarageQual  GarageCond  \
# 0            3          0          4  ...         548           4           4
# 1            3          0          2  ...         460           4           4
# 2            3          0          4  ...         608           4           4
# 3            3          0          0  ...         642           4           4
# 4            3          0          2  ...         836           4           4
#
#    PavedDrive  OpenPorchSF  MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# df.iloc[ :5, :5]

# %%
# df.iloc[ :5, 57:63]

# %%
G1= df.iloc[ :,0:21]
G2= df.iloc[ :,21:41]
G3= df.iloc[ :,41:63]

# %%
correlation = G1.corr()
correlation
# Out:
#                     Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# Id            1.000000    0.016151 -0.009639    -0.011789 -0.036507  0.006110
# MSSubClass    0.016151    1.000000  0.017811    -0.360201 -0.135995 -0.020624
# MSZoning     -0.009639    0.017811  1.000000    -0.088991 -0.023951  0.098863
# LotFrontage  -0.011789   -0.360201 -0.088991     1.000000  0.299898 -0.034653
# LotArea      -0.036507   -0.135995 -0.023951     0.299898  1.000000 -0.214624
# Street        0.006110   -0.020624  0.098863    -0.034653 -0.214624  1.000000
# LotShape      0.034822    0.099092  0.056129    -0.132124 -0.163527 -0.004063
# LandContour  -0.014571    0.004291 -0.026716    -0.071211 -0.168455  0.141590
# Utilities     0.013790   -0.023882 -0.000837    -0.000732  0.009667  0.001665
# LotConfig     0.062671    0.064806 -0.018868    -0.169329 -0.122189  0.022564
# LandSlope     0.005319   -0.012166 -0.019742     0.060073  0.456997 -0.206165
# ...

# %%
correlation = G2.corr()
correlation
# Out:
#               RoofMatl  Exterior1st  Exterior2nd  ExterQual  ExterCond  \
# RoofMatl      1.000000     0.001355    -0.003181  -0.020036  -0.044201
# Exterior1st   0.001355     1.000000     0.855486  -0.139884   0.039971
# Exterior2nd  -0.003181     0.855486     1.000000  -0.114883   0.048157
# ExterQual    -0.020036    -0.139884    -0.114883   1.000000  -0.077752
# ExterCond    -0.044201     0.039971     0.048157  -0.077752   1.000000
# Foundation   -0.039156     0.164337     0.136330  -0.476824   0.192970
# BsmtQual     -0.018673    -0.164854    -0.144061   0.596816  -0.138194
# BsmtCond     -0.011007    -0.050156    -0.052225  -0.010087   0.190424
# BsmtExposure -0.079689    -0.069389    -0.054457   0.225330  -0.073931
# BsmtFinType1 -0.021346     0.177037     0.164070  -0.049794   0.006147
# BsmtFinSF1    0.039590    -0.087729    -0.088611  -0.185331   0.032626
# BsmtFinType2 -0.021223     0.050463     0.029509  -0.076273   0.017384
# ...

# %%
correlation = G3.corr()
correlation
# Out:
#                FullBath  BedroomAbvGr  KitchenAbvGr  KitchenQual  \
# FullBath       1.000000      0.356925      0.086986    -0.357166
# BedroomAbvGr   0.356925      1.000000      0.176684     0.031919
# KitchenAbvGr   0.086986      0.176684      1.000000     0.121163
# KitchenQual   -0.357166      0.031919      0.121163     1.000000
# TotRmsAbvGrd   0.548309      0.660236      0.238162    -0.284135
# Functional     0.011202     -0.038941     -0.060759    -0.105014
# Fireplaces     0.240772      0.122398     -0.082368    -0.231935
# GarageType    -0.295944     -0.008250      0.132632     0.191346
# GarageYrBlt    0.484933     -0.073501     -0.125364    -0.392293
# GarageFinish  -0.422783      0.012230      0.134739     0.384142
# GarageCars     0.511498      0.117343      0.048042    -0.430045
# GarageArea     0.423173      0.085679      0.034285    -0.417334
# GarageQual     0.105587      0.019459     -0.118234    -0.020271
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(correlation , square = True, fmt = '.1f',annot = True, annot_kws = {'size':12})
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1346 entries, 0 to 1459
# Data columns (total 62 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1346 non-null   int64
#  1   MSSubClass     1346 non-null   int64
#  2   MSZoning       1346 non-null   int64
#  3   LotFrontage    1346 non-null   float64
#  4   LotArea        1346 non-null   int64
#  5   Street         1346 non-null   int64
#  6   LotShape       1346 non-null   int64
#  7   LandContour    1346 non-null   int64
#  8   Utilities      1346 non-null   int64
#  9   LotConfig      1346 non-null   int64
#  10  LandSlope      1346 non-null   int64
#  11  Neighborhood   1346 non-null   int64
#  12  Condition1     1346 non-null   int64
#  13  Condition2     1346 non-null   int64
#  14  BldgType       1346 non-null   int64
#  15  HouseStyle     1346 non-null   int64
#  16  OverallQual    1346 non-null   int64
#  17  OverallCond    1346 non-null   int64
# ...

# %%
df.shape
# Out:
# (1346, 62)

# %%
df.drop(['RoofStyle','OverallCond','Condition2','Condition1','Neighborhood','LandSlope','LotConfig','Utilities','LandContour','Street','LotArea','MSZoning','MSSubClass','Id'],axis=1, inplace = True)
df.drop(['Heating','BsmtFinType2','ExterCond','RoofMatl'],axis=1, inplace = True)
df.drop(['SaleType','YrSold','MoSold','Functional','BedroomAbvGr'],axis=1, inplace = True)

# %%
df.shape
# Out:
# (1346, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1346 entries, 0 to 1459
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotFrontage    1346 non-null   float64
#  1   LotShape       1346 non-null   int64
#  2   BldgType       1346 non-null   int64
#  3   HouseStyle     1346 non-null   int64
#  4   OverallQual    1346 non-null   int64
#  5   YearBuilt      1346 non-null   int64
#  6   YearRemodAdd   1346 non-null   int64
#  7   Exterior1st    1346 non-null   int64
#  8   Exterior2nd    1346 non-null   int64
#  9   ExterQual      1346 non-null   int64
#  10  Foundation     1346 non-null   int64
#  11  BsmtQual       1346 non-null   int64
#  12  BsmtCond       1346 non-null   int64
#  13  BsmtExposure   1346 non-null   int64
#  14  BsmtFinType1   1346 non-null   int64
#  15  BsmtFinSF1     1346 non-null   int64
#  16  BsmtUnfSF      1346 non-null   int64
#  17  TotalBsmtSF    1346 non-null   int64
# ...

# %%
correlation = df.corr()
correlation
# Out:
#                LotFrontage  LotShape  BldgType  HouseStyle  OverallQual  \
# LotFrontage       1.000000 -0.132124 -0.414011    0.044339     0.227328
# LotShape         -0.132124  1.000000  0.104536   -0.109312    -0.186656
# BldgType         -0.414011  0.104536  1.000000    0.050598     0.070102
# HouseStyle        0.044339 -0.109312  0.050598    1.000000     0.197311
# OverallQual       0.227328 -0.186656  0.070102    0.197311     1.000000
# YearBuilt         0.102615 -0.225033  0.228230    0.258771     0.571695
# YearRemodAdd      0.077934 -0.155525  0.121452    0.199646     0.550422
# Exterior1st       0.069300 -0.002639 -0.095374   -0.036749     0.157265
# Exterior2nd       0.092760 -0.017202 -0.129716   -0.072377     0.158066
# ExterQual        -0.180703  0.139138 -0.105859   -0.082995    -0.677787
# Foundation        0.097420 -0.164540  0.156315    0.208621     0.487805
# BsmtQual         -0.168066  0.152556 -0.117219   -0.126566    -0.608286
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(correlation , square = True, fmt = '.1f',annot = True, annot_kws = {'size':12})
# Out:
# <Axes: >

# %% [markdown]
# STEP 7: DETECT OUTLIER

# %%
for i in df.columns:
    pd.DataFrame(df[i]).boxplot()
    plt.title("Boxplot outliers appera of  " + i)
    plt.show()

# %%
df= df.drop(['YearRemodAdd','YearBuilt'], axis=1,)

# %%
for i in df.columns:
    pd.DataFrame(df[i]).boxplot()
    plt.title("Boxplot outliers appera of  " + i)
    plt.show()

# %%
# Find Value of outlire
max(df['LotFrontage'])
# Out:
# 313.0

# %%
df['LotFrontage']==313
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Name: LotFrontage, Length: 1346, dtype: bool

# %%
df[df['LotFrontage']==313]
# Out:
#       LotFrontage  LotShape  BldgType  HouseStyle  OverallQual  Exterior1st  \
# 934         313.0         1         0           2            7           12
# 1298        313.0         2         0           5           10           10
#
#       Exterior2nd  ExterQual  Foundation  BsmtQual  ...  GarageYrBlt  \
# 934            14          3           1         2  ...       1960.0
# 1298           12          0           2         0  ...       2008.0
#
#       GarageFinish  GarageCars  GarageArea  GarageQual  GarageCond  \
# 934              1           2         505           4           4
# 1298             0           2        1418           4           4
#
#       PavedDrive  OpenPorchSF  SaleCondition  SalePrice
# 934            2            0              4     242000
# 1298           2          292              5     160000
#
# [2 rows x 37 columns]

# %%
df.drop(df[df['LotFrontage']==313].index, inplace=True)

# %%
df.shape
# Out:
# (1344, 37)

# %%
max(df['BsmtFinSF1'])
# Out:
# 2260

# %%
 df.drop(df[df['BsmtFinSF1']==1904].index, inplace=True)

# %%
max(df['BsmtFinSF1'])
# Out:
# 2260

# %%
 df.drop(df[df['BsmtFinSF1']==1880].index, inplace=True)

# %%
max(df['BsmtFinSF1'])
# Out:
# 2260

# %%
 df.drop(df[df['BsmtFinSF1']==2096].index, inplace=True)

# %%
max(df['TotalBsmtSF'])
# Out:
# 3200

# %%
 df.drop(df[df['TotalBsmtSF']==3200].index, inplace=True)

# %%
max(df['TotalBsmtSF'])
# Out:
# 3138

# %%
 df.drop(df[df['TotalBsmtSF']==3094].index, inplace=True)

# %%
max(df['1stFlrSF'])
# Out:
# 3138

# %%
 df.drop(df[df['1stFlrSF']==2898].index, inplace=True)

# %%
max(df['GrLivArea'])
# Out:
# 4676

# %%
 df.drop(df[df['GrLivArea']==4316].index, inplace=True)

# %%
max(df['TotRmsAbvGrd'])
# Out:
# 12

# %%
 df.drop(df[df['TotRmsAbvGrd']==12].index, inplace=True)

# %%
max(df['GarageArea'])
# Out:
# 1390

# %%
 df.drop(df[df['GarageArea']==1390].index, inplace=True)

# %%
max(df['GarageArea'])
# Out:
# 1356

# %%
 df.drop(df[df['GarageArea']==1356].index, inplace=True)

# %%
max(df['OpenPorchSF'])
# Out:
# 547

# %%
 df.drop(df[df['OpenPorchSF']==547].index, inplace=True)

# %%
max(df['OpenPorchSF'])
# Out:
# 502

# %%
 df.drop(df[df['OpenPorchSF']==502].index, inplace=True)

# %%
max(df['OpenPorchSF'])
# Out:
# 418

# %%
 df.drop(df[df['OpenPorchSF']==418].index, inplace=True)

# %%
max(df['SalePrice'])
# Out:
# 625000

# %%
 df.drop(df[df['SalePrice']==625000].index, inplace=True)

# %%
max(df['SalePrice'])
# Out:
# 611657

# %%
 df.drop(df[df['SalePrice']==556581].index, inplace=True)

# %%
df.columns
# Out:
# Index(['LotFrontage', 'LotShape', 'BldgType', 'HouseStyle', 'OverallQual',
#        'Exterior1st', 'Exterior2nd', 'ExterQual', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtUnfSF',
#        'TotalBsmtSF', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Fireplaces', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars',
#        'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive', 'OpenPorchSF',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1322 entries, 0 to 1459
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   LotFrontage    1322 non-null   float64
#  1   LotShape       1322 non-null   int64
#  2   BldgType       1322 non-null   int64
#  3   HouseStyle     1322 non-null   int64
#  4   OverallQual    1322 non-null   int64
#  5   Exterior1st    1322 non-null   int64
#  6   Exterior2nd    1322 non-null   int64
#  7   ExterQual      1322 non-null   int64
#  8   Foundation     1322 non-null   int64
#  9   BsmtQual       1322 non-null   int64
#  10  BsmtCond       1322 non-null   int64
#  11  BsmtExposure   1322 non-null   int64
#  12  BsmtFinType1   1322 non-null   int64
#  13  BsmtFinSF1     1322 non-null   int64
#  14  BsmtUnfSF      1322 non-null   int64
#  15  TotalBsmtSF    1322 non-null   int64
#  16  HeatingQC      1322 non-null   int64
#  17  CentralAir     1322 non-null   int64
# ...

# %%
X = df.drop("SalePrice", axis=1)
y = df["SalePrice"]
len(X)
# Out:
# 1322

# %%
len(X)
X.shape
# Out:
# (1322, 36)

# %%
len(y)
y.shape
# Out:
# (1322,)

# %%
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.2, random_state=50)

# %%
print('Size of Train X', len(X_train))
print('Size of Train y',len(y_train))
print('Size of Test X',len(X_test))
print('Size of Test y',len(y_test))
# Out:
# Size of Train X 1057
# Size of Train y 1057
# Size of Test X 265
# Size of Test y 265

# %%
print("Train:", X_train.shape, "| Test:", X_test.shape)
# Out:
# Train: (1057, 36) | Test: (265, 36)

# %% [markdown]
# <!-- Linear Regression -->

# %%
X = df.drop("GarageFinish", axis = 1)
y = df["GarageFinish"]

# %%
# from sklearn.naive_bayes import GaussianNB

# %%
# gnb = GaussianNB()
# gnb.fit(X_train, y_train)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()
model.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
importances = model.feature_importances_
importances
# Out:
# array([0.04210765, 0.00961634, 0.00880268, 0.01525467, 0.02756702,
#        0.01905033, 0.02012132, 0.03126864, 0.0219162 , 0.01902779,
#        0.00458565, 0.01207639, 0.01577631, 0.0401421 , 0.04601107,
#        0.05093052, 0.01697827, 0.00037295, 0.00253526, 0.05301301,
#        0.04745518, 0.01566477, 0.00090649, 0.01591054, 0.0218827 ,
#        0.01908682, 0.0973547 , 0.08026607, 0.0124046 , 0.06824968,
#        0.00152178, 0.00137294, 0.00250186, 0.04775926, 0.00740875,
#        0.10309969])

# %%
feat_importance = pd.Series(importances, index=X.columns)
feat_importance
# Out:
# LotFrontage      0.042108
# LotShape         0.009616
# BldgType         0.008803
# HouseStyle       0.015255
# OverallQual      0.027567
# Exterior1st      0.019050
# Exterior2nd      0.020121
# ExterQual        0.031269
# Foundation       0.021916
# BsmtQual         0.019028
# BsmtCond         0.004586
# BsmtExposure     0.012076
# BsmtFinType1     0.015776
# BsmtFinSF1       0.040142
# BsmtUnfSF        0.046011
# TotalBsmtSF      0.050931
# HeatingQC        0.016978
# CentralAir       0.000373
# Electrical       0.002535
# 1stFlrSF         0.053013
# GrLivArea        0.047455
# FullBath         0.015665
# KitchenAbvGr     0.000906
# KitchenQual      0.015911
# TotRmsAbvGrd     0.021883
# Fireplaces       0.019087
# GarageType       0.097355
# GarageYrBlt      0.080266
# GarageCars       0.012405
# GarageArea       0.068250
# GarageQual       0.001522
# GarageCond       0.001373
# PavedDrive       0.002502
# OpenPorchSF      0.047759
# SaleCondition    0.007409
# ...

# %%
feat_importance.sort_values(ascending=False).plot(kind='bar')
top_features = feat_importance.sort_values(ascending=False).head(5)
print(top_features)
# Out:
# SalePrice      0.103100
# GarageType     0.097355
# GarageYrBlt    0.080266
# GarageArea     0.068250
# 1stFlrSF       0.053013
# dtype: float64

# %%
X['GarageType'].value_counts()
# Out:
# GarageType
# 1    846
# 5    364
# 3     82
# 2     18
# 4      7
# 0      5
# Name: count, dtype: int64

# %%
X['GarageType'].value_counts().sum()

# %%
X = df.drop("GarageType", axis = 1)
y = df["GarageType"]

# %%
#decrease the epoches to only 16 to overfitting removal. see where accuracy and validation gives equal results.

# %%
# training_data_prediction = gnb.predict(X_train)
# print(training_data_prediction)
# Out:
# [199900 129900 113000 ... 105000 112000 143000]

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
print("Accuracy : ",accuracy_score(y_train,training_data_prediction))
# print("Accuracy : ",accuracy_score(X_test,training_data_prediction))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7104/3166201578.py in <cell line: 0>()
# ----> 1 print("Accuracy : ",accuracy_score(y_train,training_data_prediction))
#       2 # print("Accuracy : ",accuracy_score(X_test,training_data_prediction))
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     225     # Compute accuracy for each possible representation
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.layers import Dense

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# y_train = y_train/100000
# y_test = y_test/100000

# %%
X_train.shape
# Out:
# (1057, 36)

# %%
# y_train[:4]

# %%
# X_train.shape[1]

# %%
model = Sequential()

# %%
# # input + hidden layer
# # there is 32 neurons need in the hidden layer1
# model.add(Dense(64, activation='relu', input_dim = X_train.shape[1]))
# model.add(Dense(32, activation='relu'))
# model.add(Dense(1))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#cause 1

model = Sequential([
    Dense(32, activation='relu', input_dim=X_train.shape[1]),
    Dense(3, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 32)             │         1,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,283 (5.01 KB)
#  Trainable params: 1,283 (5.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7104/531934642.py in <cell line: 0>()
# ----> 1 history=model.fit(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     117             return fn(*args, **kwargs)
#     118         except Exception as e:
# --> 119             filtered_tb = _process_traceback_frames(e.__traceback__)
# ...

# %%
# # model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.compile(optimizer='adam', loss='mse', metrics=['r2_score'])
model.fit(X_train, y_train, epochs=100 , batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 6.7945 - r2_score: -1.1766 - val_loss: 7.1439 - val_r2_score: -1.2172
# Epoch 2/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7728 - r2_score: -1.1697 - val_loss: 7.1321 - val_r2_score: -1.2135
# Epoch 3/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7653 - r2_score: -1.1673 - val_loss: 7.1266 - val_r2_score: -1.2118
# Epoch 4/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7613 - r2_score: -1.1660 - val_loss: 7.1238 - val_r2_score: -1.2110
# Epoch 5/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7592 - r2_score: -1.1653 - val_loss: 7.1223 - val_r2_score: -1.2105
# Epoch 6/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7579 - r2_score: -1.1649 - val_loss: 7.1214 - val_r2_score: -1.2102
# Epoch 7/100
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7570 - r2_score: -1.1646 - val_loss: 7.1207 - val_r2_score: -1.2100
# Epoch 8/100
# ...

# %%
pred = model.predict(X_train)
pred
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# array([[0.34560665, 0.32322195, 0.33117142],
#        [0.33859357, 0.3305594 , 0.330847  ],
#        [0.3344617 , 0.33135107, 0.33418715],
#        ...,
#        [0.31489018, 0.34031677, 0.34479302],
#        [0.3165327 , 0.3470502 , 0.33641708],
#        [0.3259567 , 0.33274418, 0.34129915]], dtype=float32)

# %%
import numpy as np
training_data_prediction = np.argmax(pred, axis =1)
training_data_prediction
# Out:
# array([0, 0, 0, ..., 2, 1, 2])

# %%
# Classification accuracy, f1_score, recall and precission.

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
print("Accuracy : ",accuracy_score(y_train,training_data_prediction))
print("Precission : ",precision_score(y_train,training_data_prediction,average='weighted'))
print("Recall_score : ",recall_score(y_train,training_data_prediction,average='weighted'))
print("F1_score : ",f1_score(y_train,training_data_prediction,average='weighted'))
# Out:
# Accuracy :  0.17975402081362346
# Precission :  0.3897914213060779
# Recall_score :  0.17975402081362343
# F1_score :  0.24356893748926392
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
pred = model.predict(X_test)
pred
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[0.34254715, 0.32584935, 0.3316035 ],
#        [0.33885708, 0.32699612, 0.33414683],
#        [0.32587123, 0.34256992, 0.3315588 ],
#        [0.3164092 , 0.3341963 , 0.34939453],
#        [0.34177327, 0.32935518, 0.32887146],
#        [0.32532996, 0.33933184, 0.33533812],
#        [0.37255862, 0.34428063, 0.28316072],
#        [0.3456395 , 0.3293964 , 0.32496414],
#        [0.31407997, 0.35726574, 0.32865432],
#        [0.3423087 , 0.33193707, 0.32575426],
#        [0.3240796 , 0.34032363, 0.33559665],
#        [0.3298123 , 0.34341404, 0.32677367],
#        [0.33819035, 0.32891005, 0.33289948],
#        [0.3333533 , 0.33220345, 0.33444315],
#        [0.33035454, 0.33418128, 0.33546412],
#        [0.34355232, 0.33222193, 0.32422575],
#        [0.3368436 , 0.344076  , 0.31908026],
#        [0.33069083, 0.33717063, 0.33213848],
#        [0.3313259 , 0.31016085, 0.35851333],
#        [0.32822523, 0.33408988, 0.33768496],
# ...

# %%
testing_data_prediction = np.argmax(pred, axis =1)
testing_data_prediction
# Out:
# array([0, 0, 1, 2, 0, 1, 0, 0, 1, 0, 1, 1, 0, 2, 2, 0, 1, 1, 2, 2, 0, 0,
#        2, 1, 1, 2, 1, 0, 2, 2, 1, 0, 0, 2, 1, 0, 0, 1, 0, 1, 0, 0, 0, 1,
#        0, 2, 0, 0, 2, 1, 0, 1, 2, 0, 2, 2, 1, 2, 0, 1, 2, 0, 0, 2, 1, 0,
#        2, 1, 0, 1, 2, 2, 1, 0, 2, 1, 0, 2, 1, 1, 2, 0, 1, 2, 0, 2, 2, 1,
#        2, 2, 0, 0, 1, 2, 2, 0, 2, 2, 0, 2, 2, 0, 1, 1, 1, 2, 2, 0, 0, 0,
#        2, 2, 1, 1, 1, 1, 1, 0, 1, 1, 2, 1, 1, 1, 0, 0, 1, 1, 0, 0, 2, 0,
#        0, 2, 2, 2, 0, 1, 0, 0, 2, 2, 0, 2, 1, 1, 0, 1, 2, 1, 2, 0, 0, 2,
#        0, 0, 2, 1, 1, 1, 2, 2, 0, 1, 0, 2, 1, 1, 0, 1, 0, 1, 2, 2, 2, 0,
#        2, 1, 0, 2, 0, 1, 2, 2, 1, 2, 1, 2, 0, 2, 0, 1, 2, 1, 0, 2, 2, 1,
#        2, 2, 2, 2, 2, 2, 2, 2, 1, 0, 2, 2, 0, 0, 0, 2, 0, 1, 0, 0, 1, 2,
#        0, 1, 0, 1, 2, 0, 2, 2, 0, 2, 0, 0, 2, 2, 2, 1, 1, 1, 1, 1, 2, 1,
#        0, 1, 2, 0, 0, 0, 2, 2, 2, 0, 2, 1, 2, 0, 1, 2, 2, 0, 2, 0, 2, 1,
#        1])

# %%
y_test.shape
testing_data_prediction.shape
# Out:
# (265,)

# %%
print("Accuracy : ",accuracy_score(y_test,testing_data_prediction))
print("Precission : ",precision_score(y_test,testing_data_prediction,average='weighted'))
print("Recall_score : ",recall_score(y_test,testing_data_prediction,average='weighted'))
print("F1_score : ",f1_score(y_test,testing_data_prediction,average='weighted'))
# Out:
# Accuracy :  0.21509433962264152
# Precission :  0.4383895068168557
# Recall_score :  0.21509433962264152
# F1_score :  0.2787047457524455
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# add one more layer of neural network
# Dropout layer useage.
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2

# %%
model = Sequential([
    Dense(32, activation='relu',kernel_regularizer=l2(0.001), input_dim=X_train.shape[1]),
    Dropout(0.3),
    Dense(3,activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 32)             │         1,184 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,283 (5.01 KB)
#  Trainable params: 1,283 (5.01 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# if model is still overfitting then change the column.

# %%
# predictions = model.predict(X_train)
# predictons = predictions*100000
# y_train = y_train*100000
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# regression absolute error mean square error

# %%
# from sklearn.metrics import(
# mean_absolute_error, mean_squared_error, r2_score,
# mean_absolute_percentage_error
# )

# r2 = r2_score(y_train, predictions)
# mea = mean_absolute_error(y_train, predictions)
# mse = mean_squared_error (y_train, predictions)
# rmse = np.sqrt(mse)
# print(f"R2 : {r2 : .4f}")
# print (f"MAE : {mea: .4f}")
# print(f"MSE : {mse : .4f}")
# print(f"RMSE : {rmse : .4f}")
# Out:
# R2 : -6.2876
# MAE :  184342.7045
# MSE :  39386747434.8989
# RMSE :  198460.9469

# %%
# predictions = model.predict(X_test)
# predictons = predictions*100000
# y_test = y_test*100000

# %%
# r2 = r2_score(y_test, predictions)
# mea = mean_absolute_error(y_test, predictions)
# mse = mean_squared_error (y_test, predictions)
# rmse = np.sqrt(mse)
# print(f"R2 : {r2 : .4f}")
# print (f"MAE : {mea: .4f}")
# print(f"MSE : {mse : .4f}")
# print(f"RMSE : {rmse : .4f}")
